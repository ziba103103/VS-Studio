# %% [markdown]
# ## Область определения

# %%
from sympy import Symbol, S
from sympy.calculus.util import continuous_domain 
x = Symbol("x") 
f = (x**3)/(x**2-1) 
continuous_domain(f, x, S.Reals)
# Out:
# Union(Interval.open(-oo, -1), Interval.open(-1, 1), Interval.open(1, oo))

# %%
from sympy import Symbol, S
from sympy.calculus.util import continuous_domain 
x = Symbol("x") 
f = (x**3)/(x+5)**2
continuous_domain(f, x, S.Reals)
# Out:
# Union(Interval.open(-oo, -5), Interval.open(-5, oo))

# %% [markdown]
# ## Область значений функции

# %%
from sympy import Symbol, S
from sympy.calculus.util import function_range
x = Symbol("x") 
f = (x**3)/(x**2-1) 
function_range(f, x, S.Reals)
# Out:
# Interval(-oo, oo)

# %%
from sympy import Symbol, S
from sympy.calculus.util import function_range
x = Symbol("x") 
f = (x**3)/(x+5)**2
function_range(f, x, S.Reals)
# Out:
# Interval(-oo, oo)

# %% [markdown]
# ## Нахождение точек пересечения с осями координат

# %%
from sympy import solveset, Eq
f = (x**3)/(x**2-1) 
solveset(Eq(f, 0), x)
# Out:
# {0}

# %%
x = Symbol("x")
f = (x**3)/(x**2-1)
f.subs(x, 0)
# Out:
# 0

# %%
from sympy import solveset, Eq
f = (x**3)/(x+5)**2
solveset(Eq(f, 0), x)
# Out:
# {0}

# %%
x = Symbol("x")
f = (x**3)/(x+5)**2
f.subs(x, 0)
# Out:
# 0

# %%
from sympy import solveset, Eq
f = (x**3)/(x+5)**2
solveset(Eq(f, 0), x)
# Out:
# {0}

# %%
y = Symbol("y")
f = (x**3)/(x+5)**2
f.subs(y, 0)
# Out:
# x**3/(x + 5)**2

# %% [markdown]
# ## Нахождение производной

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = (x**3)/(x**2-1)
expr.diff(x)
# Out:
# -2*x**4/(x**2 - 1)**2 + 3*x**2/(x**2 - 1)

# %%
y = expr.diff(x)
solveset(Eq(y, 0), x)
# Out:
# {0, -sqrt(3), sqrt(3)}

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = (x**3)/(x+5)**2
expr.diff(x)
# Out:
# -2*x**3/(x + 5)**3 + 3*x**2/(x + 5)**2

# %% [markdown]
# точки макс и мин

# %%
y = expr.diff(x)
solveset(Eq(y, 0), x)
# Out:
# {-15, 0}

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = (x**2+1)/x
expr.diff(x)
# Out:
# 2 - (x**2 + 1)/x**2

# %%
y = expr.diff(x)
solveset(Eq(y, 0), x)
# Out:
# {-1, 1}

# %% [markdown]
# ## Нахождение второй производной

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = (x**3)/(x**2-1)
expr.diff(x,2)
# Out:
# 2*x*(x**2*(4*x**2/(x**2 - 1) - 1)/(x**2 - 1) - 6*x**2/(x**2 - 1) + 3)/(x**2 - 1)

# %%
y = expr.diff(x,2)
solveset(Eq(y, 0), x)
# Out:
# {0, -sqrt(3)*I, sqrt(3)*I}

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = (x**3)+15*x**2/(2*(x+5)**3)
expr.diff(x,2)
# Out:
# 3*(30*x**2/(x + 5)**5 + 2*x - 30*x/(x + 5)**4 + 5/(x + 5)**3)

# %%
y = expr.diff(x,2)
solveset(Eq(y, 0), x)
# Out:
# {CRootOf(2*x**6 + 50*x**5 + 500*x**4 + 2500*x**3 + 6255*x**2 + 6150*x + 125, 0), CRootOf(2*x**6 + 50*x**5 + 500*x**4 + 2500*x**3 + 6255*x**2 + 6150*x + 125, 1), CRootOf(2*x**6 + 50*x**5 + 500*x**4 + 2500*x**3 + 6255*x**2 + 6150*x + 125, 2), CRootOf(2*x**6 + 50*x**5 + 500*x**4 + 2500*x**3 + 6255*x**2 + 6150*x + 125, 3), CRootOf(2*x**6 + 50*x**5 + 500*x**4 + 2500*x**3 + 6255*x**2 + 6150*x + 125, 4), CRootOf(2*x**6 + 50*x**5 + 500*x**4 + 2500*x**3 + 6255*x**2 + 6150*x + 125, 5)}

# %% [markdown]
# ## Нахождение асимптот

# %% [markdown]
# задание

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x+5)**2
limit(f,x,oo)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x+5)**2
limit(f,x,1)
# Out:
# 1/36

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x+5)**2
limit(f,x,-1)
# Out:
# -1/16

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x+5)**2
limit(f,x,oo)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x+5)**2
limit(f,x,oo)
# Out:
# oo

# %% [markdown]
# урок

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x**2-1)
limit(f,x,oo)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x**2-1)
limit(f,x,1)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/(x**2-1)
limit(f,x,-1)
# Out:
# oo

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/((x**2-1)*x)
limit(f,x,oo)
# Out:
# 1

# %%
from sympy import Symbol, limit, oo
x = Symbol("x")
f = (x**3)/((x**2-1)) - 1*x
limit(f,x,oo)
# Out:
# 0

# %%
import math
print(round(1/(1+math.exp(-2*(1+1+0))),2))
print(round(1/(1+math.exp(-2*(0.1+0.3+0.6))),2))
# Out:
# 0.98
# 0.88

# %% [markdown]
# производные

# %%
from sympy import symbols, cos, diff

a, b, c = symbols('a b c', real=True)
f = 5*a*b - a*cos(c) + a**8 + c**2*b

print(diff(f, a))
# Out:
# 8*a**7 + 5*b - cos(c)

# %%
from sympy import *
 
x, y = symbols('x, y')
eq1 = Eq(3*x**2+3*y**2-15,0)
eq2 = Eq(6*x*y-12, 0)
 
sol = solve([eq1, eq2], [x, y])
sol
# Out:
# [(-2, -1), (-1, -2), (1, 2), (2, 1)]

# %% [markdown]
# функция банана или функция долины

# %%
import numpy as np
 
def func_rosen(x):
    r = np.sum(100*(x[1:]-x[:-1]**2)**2 + (1-x[:-1])**2, axis=0)
    return r

# %%
import matplotlib.pyplot as plt
graph = plt.figure(figsize=[25, 15])
ax = graph.add_subplot(projection='3d')
ax.view_init(45, 30)
x1 = np.arange(-3, 3, 0.2)
x2 = np.arange(-2, 4, 0.2)
x1, x2 = np.meshgrid(x1, x2)
y = func_rosen(np.array([x1,x2]))
surf = ax.plot_surface(x1, x2, y)
plt.show()

# %% [markdown]
# я метод Пауэлла

# %%
from scipy.optimize import minimize
x1 = np.array([2.4, 1.5, 2.1, 0.7, 1.1])
result_point = minimize(func_rosen, x1, method='powell')
print(result_point.x)
# Out:
# [1. 1. 1. 1. 1.]

# %% [markdown]
# м метода Нелдера — Мида

# %%
from scipy.optimize import minimize
x1 = np.array([2.4, 1.5, 2.1, 0.7, 1.1])
result_point = minimize(func_rosen, x1, method='nelder-mead')
print(result_point.x)
# Out:
# [1.02760651 1.05589639 1.11509457 1.2440091  1.54862169]

# %%
import numpy as np
def func_rosen(x):
    r = np.sum(100*(x[1:]-x[:-1]**2)**2 + (1-x[:-1])**2, axis=0)
    return r
 
 
from scipy.optimize import least_squares
x1 = np.array([2.4, 1.5, 2.1, 0.7, 1.1])
res =  least_squares(func_rosen, x1)
print(res.x)
# Out:
# [0.93865173 0.88210868 0.776457   0.60278764 0.36076162]

# %%
import matplotlib.pyplot as plt
graph = plt.figure(figsize=[25, 15])
ax = graph.add_subplot(projection='3d')
ax.view_init(45, 30)
x1 = np.arange(-3, 3, 0.000001)
x2 = np.arange(-1, 3, 0.2)
x1, x2 = np.meshgrid(x1, x2)
y = func_rosen(np.array([x1,x2]))
surf = ax.plot_surface(x1, x2, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 9
#       7 x1, x2 = np.meshgrid(x1, x2)
#       8 y = func_rosen(np.array([x1,x2]))
# ----> 9 surf = ax.plot_surface(x1, x2, y)
#      10 plt.show()
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2315, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, axlim_clip, **kwargs)
#    2312         color = self._get_lines.get_next_color()
#    2313     color = np.array(mcolors.to_rgba(color))
# -> 2315     polyc = art3d.Poly3DCollection(
#    2316         polys, facecolors=color, shade=shade, lightsource=lightsource,
#    2317         axlim_clip=axlim_clip, **kwargs)
#    2319 self.add_collection(polyc)
#    2320 self.auto_scale_xyz(X, Y, Z, had_data)
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\mpl_toolkits\mplot3d\art3d.py:1029, in Poly3DCollection.__init__(self, verts, zsort, shade, lightsource, axlim_clip, *args, **kwargs)
#    1025     if facecolors is None and edgecolors is None:
#    1026         raise ValueError(
#    1027             "You must provide facecolors, edgecolors, or both for "
#    1028             "shade to work.")
# -> 1029 super().__init__(verts, *args, **kwargs)
#    1030 if isinstance(verts, np.ndarray):
#    1031     if verts.ndim != 3:
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\matplotlib\collections.py:1212, in PolyCollection.__init__(self, verts, sizes, closed, **kwargs)
#    1210 super().__init__(**kwargs)
#    1211 self.set_sizes(sizes)
# -> 1212 self.set_verts(verts, closed)
#    1213 self.stale = True
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\mpl_toolkits\mplot3d\art3d.py:1090, in Poly3DCollection.set_verts(self, verts, closed)
#    1076 def set_verts(self, verts, closed=True):
#    1077     """
#    1078     Set 3D vertices.
#    1079
#    (...)   1088         connection at the end.
#    1089     """
# -> 1090     self._get_vector(verts)
#    1091     # 2D verts will be updated at draw time
#    1092     super().set_verts([], False)
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\mpl_toolkits\mplot3d\art3d.py:1067, in Poly3DCollection._get_vector(self, segments3d)
#    1065 """Optimize points for projection."""
#    1066 if len(segments3d):
# -> 1067     xs, ys, zs = np.vstack(segments3d).T
#    1068 else:  # vstack can't stack zero arrays.
#    1069     xs, ys, zs = [], [], []
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\numpy\_core\shape_base.py:291, in vstack(tup, dtype, casting)
#     289 if not isinstance(arrs, tuple):
#     290     arrs = (arrs,)
# --> 291 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:

# %% [markdown]
# → Разумеется, при решении  прикладных задач «красивые» ответы обычно не получаются, поэтому проще решать такие системы с помощью Python или любым удобным для вас способом (чуть далее мы рассмотрим полностью программное решение).

# %%
from sympy import *
a,b,w=symbols(' a b w' )
g = 3*a**2 + a + 4*b + 5*b**2
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 200
print('Функция ограничений: ', q,'= 0')
f = 3*a**2 + a + 4*b + 5*b**2 + w*(a + b - 200)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')
fw = f.diff(w)
print('df/dw =',fw,'= 0')
sols = solve([fa,fb,fw],a,b,w)
print('Стационарная точка M(x,y):\n',float(sols[a]),',',float(sols[b]))

#Целевая функция для аргументов a и b :
#f =  3*a**2 + a + 5*b**2 + 4*b
#Функция ограничений:  a + b - 200 = 0
#Функция Лагранжа :
#3*a**2 + a + 5*b**2 + 4*b + w*(a + b - 200)
#df/da = 6*a + w + 1 = 0
#df/db = 10*b + w + 4 = 0
#df/dw = a + b - 200 = 0
#Стационарная точка M(x,y):
#125.1875 , 74.8125
# Out:
# Целевая функция для аргументов a и b :
#  f =  3*a**2 + a + 5*b**2 + 4*b
# Функция ограничений:  a + b - 200 = 0
# Функция Лагранжа :
#   3*a**2 + a + 5*b**2 + 4*b + w*(a + b - 200)
# df/da = 6*a + w + 1 = 0
# df/db = 10*b + w + 4 = 0
# df/dw = a + b - 200 = 0
# Стационарная точка M(x,y):
#  125.1875 , 74.8125

# %%
from sympy import *
x,y,w=symbols(' x y w' )
g = ((x-2)**2+(y-1)**2)**(0.5)
q = x + y - 1
f = ((x-2)**2+(y-1)**2)**(0.5) + w*(x + y - 1)
fx = f.diff(x)
fy = f.diff(y)
fw = f.diff(w)
sols = solve([fx,fy,fw],x,y,w)
sols
# Out:
# [(1.00000000000000, 0.0, 0.707106781186548)]

# %%
# Импортируем все необходимые функции из библиотеки SymPy
from sympy import init_printing, solve, symbols

# Подключаем аккуратный вывод формул
init_printing()

# Создаём переменные
x1, x2, x1_tilde, lambda1, lambda2 = symbols(
    "x_1 x_2 xtilde_2 \lambda_1 \lambda_2", real=True
)

# Пишем систему уравнений для переменных
dLdx1 = -x2 + lambda1 - lambda2
dLdx2 = -x1 + lambda1
dLdx1_tilde = 2 * lambda2 * x1_tilde
dLdlambda1 = x1 + x2 - 10
dLdlambda2 = -x1 + 6 + x1_tilde**2

# Решаем систему уравнений с помощью функции solve
solution = solve(
    [dLdx1, dLdx2, dLdx1_tilde, dLdlambda1, dLdlambda2],
    x1,
    x2,
    x1_tilde,
    lambda1,
    lambda2,
)

print(solution)
# Out:
# [(6, 4, 0, 6, 2)]
# <>:9: SyntaxWarning: invalid escape sequence '\l'
# <>:9: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4976\3823877321.py:9: SyntaxWarning: invalid escape sequence '\l'
#   "x_1 x_2 xtilde_2 \lambda_1 \lambda_2", real=True

# %%
from sympy import *

a,b,c,w=symbols('a b c w')
g = 2*(a*b + a*c + b*c)

L = 2*(a*b + a*c + b*c) + w*(a*b*c - 1)

L_a = L.diff(a)
L_b = L.diff(b)
L_c = L.diff(c)
L_w = L.diff(w)

print(solve([L_a, L_b, L_c, L_w], a, b, c, w)[0])
# Out:
# (1, 1, 1, -4)

# %%
from sympy import *
a, b, w, mu1, mu2 = symbols('a b w mu1 mu2', real=True)
g = a**2 + 2*a*b + b**2
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 2
print('Функция ограничений: ', q,'= 0')
f = a**2 + 2*a*b + b**2 + w*(a + b - 2) + mu1*(a - 5) + mu2*(a - 8)
print('Функция Лагранжа: L =', f)

fa = f.diff(a)
print('∂L/∂a =', fa, '= 0')
fb = f.diff(b)
print('∂L/∂b =', fb, '= 0')
fw = f.diff(w)
print('∂L/∂w =', fw, '= 0')

sols = solve([fa, fb, fw], [a, b, w, mu1, mu2], dict=True)
print('\nРешение системы:')

print('Решения системы KKT:')
for sol in sols:
    print(f'a = {sol[a]}, b = {sol[b]}, w = {sol[w]}, mu1 = {sol[mu1]}, mu2 = {sol[mu2]}')
# Out:
# Целевая функция для аргументов a и b :
#  f =  a**2 + 2*a*b + b**2
# Функция ограничений:  a + b - 2 = 0
# Функция Лагранжа: L = a**2 + 2*a*b + b**2 + mu1*(a - 5) + mu2*(a - 8) + w*(a + b - 2)
# ∂L/∂a = 2*a + 2*b + mu1 + mu2 + w = 0
# ∂L/∂b = 2*a + 2*b + w = 0
# ∂L/∂w = a + b - 2 = 0
#
# Решение системы:
# Решения системы KKT:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 22
#      20 print('Решения системы KKT:')
#      21 for sol in sols:
# ---> 22     print(f'a = {sol[a]}, b = {sol[b]}, w = {sol[w]}, mu1 = {sol[mu1]}, mu2 = {sol[mu2]}')
#
# KeyError: b

# %%
from sympy import *

a, b, w, mu1, mu2 = symbols('a b w mu1 mu2', real=True)

f = a**2 + 2*a*b + b**2 + w*(a + b - 2) + mu1*(a - 5) + mu2*(a - 8)

fa = f.diff(a)
fb = f.diff(b)
fw = f.diff(w)

# Решаем систему
sols = solve([fa, fb, fw], [a, b, w, mu1, mu2], dict=True)
print('Решения системы:')

if sols:
    for i, sol in enumerate(sols, 1):
        print(f'\nРешение {i}:')
        # Проверяем, есть ли переменная в решении
        if a in sol:
            print(f'  a = {sol[a]}')
        if b in sol:
            print(f'  b = {sol[b]}')
        if w in sol:
            print(f'  w = {sol[w]}')
else:
    print('Явных решений нет')
# Out:
# Решения системы:
#
# Решение 1:
#   a = 2 - b
#   w = -4

# %% [markdown]
# градиент

# %%
import numpy as np

# %%
f = np.array([3, 7, 14, 23, 36, 47], dtype=float)
 
np.gradient(f)

# array([ 4. ,  5.5,  8. , 11. , 12. , 11. ])
# Out:
# array([ 4. ,  5.5,  8. , 11. , 12. , 11. ])

# %%
print(f[1] - f[0], f[-1] - f[-2])
# Out:
# 4.0 11.0

# %%
(f[2] - f[0])/2 # 5.5
(f[3] - f[1])/2 # 8.0
(f[4] - f[2])/2 # 11.0
(f[5] - f[3])/2 # 12.0
# Out:
# np.float64(12.0)

# %%
np.gradient(f, 2)

# array([2.  , 2.75, 4.  , 5.5 , 6.  , 5.5 ])
for i in range(1, len(f) - 1):
   print((f[i + 1] - f[i - 1])/(2*2))
#2.75
#4.0
#5.5
#6.0
# Out:
# 2.75
# 4.0
# 5.5
# 6.0

# %%
f = np.array([8, 2, 8, 3, 5, 6, 5, 15])
np.gradient(f, 7)
# Out:
# array([-0.85714286,  0.        ,  0.07142857, -0.21428571,  0.21428571,
#         0.        ,  0.64285714,  1.42857143])

# %%
np.gradient(f, 7)

for i in range(1, len(f) - 1):
   print((f[i + 1] - f[i - 1])/(2*2))
# Out:
# 0.0
# 0.25
# -0.75
# 0.75
# 0.0
# 2.25

# %%
def fun(x, y, a=1, b=1):
    return a * (x ** 2) + b * (y ** 2)
def grad(x, y, a=1, b=1):
	 return np.array([2 * a * x, 2 * b * y])

# %%
def grad_descend(grad, step_size=0.2, num_steps=30):
    lst = []
    x = np.random.uniform(0, 3, size = 2)
    lst.append(x)
    for i in range(num_steps):
        x = x - step_size * grad(lst[-1][0], lst[-1][1])
        lst.append(x)
    return np.array(lst)

# %%
def plot_grad(fun, trace):
    fig = plt.figure(figsize=(10, 8))
    x_ = np.linspace(-1, 1, 100)
    y_ = np.linspace(-1, 1, 100)
    x, y = np.meshgrid(x_, y_)
    z = fun(x, y)
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    ax.plot_surface(x, y, z, alpha=0.6)
    ax.contour(x, y, z, zdir='z', offset=z.min())
    z_trace = fun(trace[:, 0], trace[:, 1])
    ax.plot(trace[:, 0], trace[:, 1], z_trace, "o-")
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(y.min(), y.max())
    ax.set_zlim(z.min(), z.max())

# %%
import matplotlib as plt
trace = grad_descend(grad, 0.1, 20)
plot_grad(fun, trace = trace)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 import matplotlib as plt
#       2 trace = grad_descend(grad, 0.1, 20)
# ----> 3 plot_grad(fun, trace = trace)
#
# Cell In[62], line 2, in plot_grad(fun, trace)
#       1 def plot_grad(fun, trace):
# ----> 2     fig = plt.figure(figsize=(10, 8))
#       3     x_ = np.linspace(-1, 1, 100)
#       4     y_ = np.linspace(-1, 1, 100)
#
# TypeError: 'module' object is not callable
