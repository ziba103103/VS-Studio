# %% [markdown]
# ## Равномерное распределение

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
from scipy.stats import randint

# %%
x = np.arange(1, 7)
disc_uni_dist = randint(1, 7)
pmf = disc_uni_dist.pmf(x)
print(pmf)
# Out:
# [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]

# %%
cdf = disc_uni_dist.cdf(x)
print(cdf)
# Out:
# [0.16666667 0.33333333 0.5        0.66666667 0.83333333 1.        ]

# %%
x = np.arange(1, 251)
disc_uni_dist = randint(1,251)
cdf = disc_uni_dist.cdf(x)
print(cdf[49])
# Out:
# 0.2

# %% [markdown]
# ## Распределение Бернулли

# %%
from scipy.stats import bernoulli
import seaborn as sns

# %%
data = bernoulli.rvs(size=500,p=0.6)
ax = sns.distplot(data,
                  kde = False,
                  color='dodgerblue')
ax.set(xlabel='Значение случайной величины', ylabel='Частота')
# Out:
# [Text(0.5, 0, 'Значение случайной величины'), Text(0, 0.5, 'Частота')]

# %%
unique, counts = np.unique(data, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[  0 209]
#  [  1 291]]

# %% [markdown]
# ## Биномиальное распределение

# %%
from numpy import random

# %%
x = random.binomial(n=10, p=0.5, size=10)
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Распределение Пуассона

# %%
import scipy

# %%
scipy.stats.distributions.poisson.pmf(5, 4.5)
# Out:
# np.float64(0.17082685848611215)

# %%
sns.distplot(random.poisson(lam=3, size=1000), kde=False)
# Out:
# <Axes: >

# %%
from numpy import random
import seaborn as sns

data = random.poisson(lam=0.25, size=100)
ax = sns.displot(data, kde=False, color='dodgerblue')
ax.set(xlabel='Значение случайной величины', ylabel='Частота')

# %%
sns.distplot(random.poisson(lam=4, size=16), kde=False)
# Out:
# <Axes: >

# %%
import scipy

scipy.stats.distributions.poisson.pmf(16, 16)
# Out:
# np.float64(0.09921753162215541)

# %% [markdown]
# неппрерывное распределение

# %%
from scipy.stats import uniform
import seaborn as sns

data = uniform.rvs(size=10000, loc=10, scale=30)
ax = sns.displot(data, kde=True, bins=50)
ax.set(xlabel='Равномерное распределение', ylabel='Плотность')

# %% [markdown]
# норм распределение

# %%
from scipy.stats import norm
import seaborn as sns

data = norm.rvs(size=10000, loc=4, scale=5)
ax = sns.displot(data, kde=True, bins=50)
ax.set(xlabel='Нормальное распределение', ylabel='Плотность')

# %%
from numpy import asarray
from sklearn.preprocessing import StandardScaler
data = asarray([[93, 44],
                [4, 2],
                [36, 1],
                [14, 29],
                [78, 21]])
print(data)
scaler = StandardScaler()
scaled = scaler.fit_transform(data)
print(scaled)
# Out:
# [[93 44]
#  [ 4  2]
#  [36  1]
#  [14 29]
#  [78 21]]
# [[ 1.37243726  1.50201177]
#  [-1.17229016 -1.06239857]
#  [-0.25733199 -1.12345596]
#  [-0.88636573  0.58615094]
#  [ 0.94355062  0.09769182]]

# %%
from numpy import asarray
from sklearn.preprocessing import StandardScaler
data = asarray([[4],[25]])
print(data)
scaler = StandardScaler()
scaled = scaler.fit_transform(data)
print(scaled)
# Out:
# [[ 4]
#  [25]]
# [[-1.]
#  [ 1.]]

# %%
from scipy.stats import expon
import seaborn as sns

data = expon.rvs(scale=1, loc=0, size=1000)
ax = sns.displot(data, kde=True, bins=50)
ax.set(xlabel='Экспоненциальное распределение', ylabel='Плотность')

# %%
from scipy.stats import expon
import seaborn as sns

data = expon.rvs(scale=2, loc=0, size=30)
ax = sns.displot(data, kde=True, bins=50)
ax.set(xlabel='Экспоненциальное распределение', ylabel='Плотность')

# %%
P_at_least_1 = 1 - np.exp(-(0.1)*(7)) 
P_at_least_1
P_at_least_2 = (1 - np.exp(-(0.1)*(7)) ) - (1 - np.exp(-(0.1)*(9)) )
P_at_least_2
# Out:
# np.float64(-0.0900156440508103)
