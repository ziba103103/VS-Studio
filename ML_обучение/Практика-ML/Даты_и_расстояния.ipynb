# %%
import pandas as pd

from geopy.geocoders import Nominatim

# %% [markdown]
# # Загрузка данных

# %%
# %%capture
# !wget https://www.dropbox.com/s/64ol9q9ssggz6f1/data_ford_price.xlsx

# %%
data = pd.read_excel('C:\\Users\\Admin\\Desktop\\Data_pandas/data_ford_price.xlsx') 
data
# Out:
#       price  year  condition  cylinders  odometer title_status transmission  \
# 0     43900  2016          4          6     43500        clean    automatic
# 1     15490  2009          2          8     98131        clean    automatic
# 2      2495  2002          2          8    201803        clean    automatic
# 3      1300  2000          1          8    170305      rebuilt    automatic
# 4     13865  2010          3          8    166062        clean    automatic
# ...     ...   ...        ...        ...       ...          ...          ...
# 7012  22500  2015          3          6     23500        clean    automatic
# 7013   5975  2005          2          8         0        clean    automatic
# 7014   9999  2006          3          8    161514        clean    automatic
# 7015  10900  2011          2          8    164000        clean    automatic
# 7016  18000  2010          2          8    104000        clean    automatic
#
#      drive       size        lat        long  weather
# ...

# %% [markdown]
# # Обработка географических данных

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
from geopy.geocoders import Nominatim

# %%
Latitude = str(data['lat'][5])
Longitude =  str(data['long'][5])
location = geolocator.reverse(Latitude+","+Longitude)
print(location)
# Out:
# E&J Motors, 622, Southeast 82nd Avenue, Montavilla, Portland, Multnomah County, Oregon, 97216, United States

# %%
from geopy.geocoders import Nominatim
import time
from geopy.exc import GeocoderTimedOut

geolocator = Nominatim(user_agent="your_app_name", timeout=10)

def reverse_geocode_with_retry(lat, lon, max_retries=3):
    for attempt in range(max_retries):
        try:
            location = geolocator.reverse(f"{lat}, {lon}")
            return location
        except GeocoderTimedOut:
            if attempt < max_retries - 1:
                wait_time = (attempt + 1) * 2  # Увеличиваем задержку
                print(f"Таймаут, повтор через {wait_time} сек...")
                time.sleep(wait_time)
            else:
                print("Не удалось получить ответ после нескольких попыток")
                return None

# Использование
location = reverse_geocode_with_retry(data['lat'][0], data['long'][0])
if location:
    print(location)
# Out:
# Fort Henry Drive, Kingsport, Sullivan County, East Tennessee, Tennessee, 37663, United States

# %%
address = location.raw['address']
address[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 address = location.raw['address']
# ----> 2 address[6]
#
# KeyError: 6

# %% [markdown]
# # Отрисовка карты

# %%
#!pip install geopandas
#!pip install shapely

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt

# %%
geometry = [Point(xy) for xy in zip(data['long'], data['lat'])]
gdf = GeoDataFrame(data, geometry=geometry)  
 
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(15, 15)), marker='o', color='green', markersize=15)
 
plt.title('Расположение автомобилей на карте мира')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 geometry = [Point(xy) for xy in zip(data['long'], data['lat'])]
#       2 gdf = GeoDataFrame(data, geometry=geometry)
# ----> 4 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       5 gdf.plot(ax=world.plot(figsize=(15, 15)), marker='o', color='green', markersize=15)
#       7 plt.title('Расположение автомобилей на карте мира')
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\geopandas\datasets\__init__.py:18, in get_path(dataset)
#      12 error_msg = (
#      13     "The geopandas.dataset has been deprecated and was removed in GeoPandas "
#      14     f"1.0. You can get the original '{dataset}' data from "
#      15     f"{ne_message if 'natural' in dataset else nybb_message}"
#      16 )
#      17 if dataset in _prev_available:
# ...

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt
 
geometry = [Point(xy) for xy in zip(data['long'], data['lat'])]
gdf = GeoDataFrame(data, geometry=geometry)  
 
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(15, 15)), marker='o', color='green', markersize=15)
 
plt.title('Расположение автомобилей на карте мира')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 9
#       6 geometry = [Point(xy) for xy in zip(data['long'], data['lat'])]
#       7 gdf = GeoDataFrame(data, geometry=geometry)
# ----> 9 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#      10 gdf.plot(ax=world.plot(figsize=(15, 15)), marker='o', color='green', markersize=15)
#      12 plt.title('Расположение автомобилей на карте мира')
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\geopandas\datasets\__init__.py:18, in get_path(dataset)
#      12 error_msg = (
#      13     "The geopandas.dataset has been deprecated and was removed in GeoPandas "
#      14     f"1.0. You can get the original '{dataset}' data from "
#      15     f"{ne_message if 'natural' in dataset else nybb_message}"
#      16 )
#      17 if dataset in _prev_available:
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Загружаем карту мира из Natural Earth
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# ИЛИ если это не работает, используйте прямой URL:
# world = gpd.read_file('https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip')

# Ваш код для создания точек
geometry = [Point(xy) for xy in zip(data['long'], data['lat'])]
gdf = gpd.GeoDataFrame(data, geometry=geometry)

# Строим карту
fig, ax = plt.subplots(figsize=(15, 10))
world.plot(ax=ax, color='lightgray', edgecolor='black')
gdf.plot(ax=ax, marker='o', color='green', markersize=15, alpha=0.7)

plt.title('Расположение автомобилей на карте мира')
plt.xlabel('Долгота')
plt.ylabel('Широта')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 6
#       3 from shapely.geometry import Point
#       5 # Загружаем карту мира из Natural Earth
# ----> 6 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       7 # ИЛИ если это не работает, используйте прямой URL:
#       8 # world = gpd.read_file('https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip')
#       9
#      10 # Ваш код для создания точек
#      11 geometry = [Point(xy) for xy in zip(data['long'], data['lat'])]
#
# File c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\geopandas\datasets\__init__.py:18, in get_path(dataset)
#      12 error_msg = (
#      13     "The geopandas.dataset has been deprecated and was removed in GeoPandas "
#      14     f"1.0. You can get the original '{dataset}' data from "
# ...

# %%
import plotly.express as px
 
fig = px.scatter_geo(data,lat='lat',lon='long', hover_name="price")
fig.update_layout(title = 'Интерактивная карта цены автомобиля в зависимости от локации', title_x=1)
fig.show()
# Out:
# c:\Users\Admin\Desktop\VS Studio\.venv\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
