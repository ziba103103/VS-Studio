# %%
import pandas as pd
import numpy as np

# %%
sample_new = pd.read_csv('C:\\Users\\Admin\\Desktop\\Data_pandas/sample_submission_new.csv') 
X_train  = pd.read_csv('C:\\Users\\Admin\\Desktop\\Data_pandas/train_new.csv') 
x_test = pd.read_csv('C:\\Users\\Admin\\Desktop\\Data_pandas/test_new.csv')
