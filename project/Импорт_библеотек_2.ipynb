# %% [markdown]
# # Библиотеки

# %% [markdown]
# ## Standard library - Стандартная библиотека

# %%
import warnings  # Отключает/обрабатывает предупреждения
import os  # Работа с файловой системой
import time  # Работа со временем и паузами
from io import StringIO  # Работа со строкой как с файлом
import sys  # Доступ к системным параметрам
import json  # Чтение/запись JSON-файлов
import math  # Математические функции
import random  # Генерация случайных чисел
from itertools import chain, tee  # Работа с итераторами
from contextlib import contextmanager  # Создание контекстных менеджеров

# %% [markdown]
# ## Data handling - Обработка данных

# %%
import pandas as pd  # Основная библиотека для табличных данных
import numpy as np  # Математические операции с массивами
import statistics  # Базовые статистические функции
from numpy import array, zeros, ones  # Создание специальных массивов
from pandas import DataFrame, Series  # Основные структуры данных pandas
import scipy as sp
import statsmodels.api as sm

# %% [markdown]
# ## Geospatial - Геопространственные данные

# %%
from geopy.geocoders import Nominatim  # Преобразует адреса в координаты (широта/долгота)
import geopandas as gpd  # Работа с геоданными (карты, границы, точки)
from shapely.geometry import Point, Polygon  # Создание геометрических объектов (точка, полигон)
from geopy.geocoders import Nominatim  # Дублирующийся импорт (можно удалить строку)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from geopy.geocoders import Nominatim  # Преобразует адреса в координаты (широта/долгота)
# ----> 2 import geopandas as gpd  # Работа с геоданными (карты, границы, точки)
#       3 from shapely.geometry import Point, Polygon  # Создание геометрических объектов (точка, полигон)
#       4 from geopy.geocoders import Nominatim  # Дублирующийся импорт (можно удалить строку)
#
# ModuleNotFoundError: No module named 'geopandas'

# %% [markdown]
# ## SciPy / Statistics - SciPy / Статистика

# %%
import scipy as sp  # Основной модуль для научных вычислений
import scipy.stats as stats  # Статистические функции и тесты
from scipy.spatial import ConvexHull  # Вычисление выпуклой оболочки точек
from scipy.spatial import KDTree  # Структура для быстрого поиска соседних точек
from scipy import linalg as la  # Линейная алгебра (матричные операции)

# %% [markdown]
# ## Statsmodels - Statsmodels (библиотека статистического моделирования)

# %%
import statsmodels.api as sm  # Основной модуль для статистических моделей
from statsmodels import stats as sms  # Дополнительные статистические функции
from statsmodels.stats.anova import AnovaRM  # Повторные измерения ANOVA
from statsmodels.stats.descriptivestats import sign_test  # Знаковый тест
from statsmodels.stats.contingency_tables import mcnemar  # Тест Макнемара
from statsmodels.tsa.arima.model import ARIMA  # ARIMA модель для временных рядов
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf  # Графики автокорреляции
from statsmodels.tsa.statespace.sarimax import SARIMAX  # Расширенная сезонная ARIMA

# %% [markdown]
# ## Profiling / Visualization tools - Инструменты профилирования/визуализации

# %%
# (закомментирована)
from ydata_profiling import ProfileReport  # Генератор отчётов по данным (ранее pandas-profiling)
import sweetviz as sv  # Анализатор и визуализатор данных с сравнением выборок
import dtale  # Интерактивный веб-интерфейс для анализа DataFrame

# %% [markdown]
# ## ML / AI frameworks - МЛ / ИИ-фреймворки

# %%
import torch  # Фреймворк для глубокого обучения
from lightautoml.automl.presets.tabular_presets import TabularAutoML  # Автоматический ML для табличных данных
from lightautoml.tasks import Task  # Определение типа задачи ML
import arch  # Моделирование волатильности (GARCH, ARCH)
from arch import arch_model  # Функция для создания ARCH/GARCH моделей
import sklearn as sk  # Основная библиотека машинного обучения
from sklearn import datasets  # Загрузка стандартных наборов данных

# %% [markdown]
# ## Visualization libraries - Библиотеки визуализации

# %%
import plotly  # Интерактивная визуализация (веб-графика)
import plotly.express as px  # Упрощённый API plotly для быстрых графиков
import seaborn as sns  # Статистическая визуализация поверх matplotlib
import matplotlib.pyplot as plt  # Основная библиотека для статичных графиков
import matplotlib  # Основной модуль matplotlib
import matplotlib.style as style  # Управление стилями графиков matplotlib

# %% [markdown]
# ## Data sources / preprocessing - Источники данных/предобработка

# %%
from sklearn.datasets import fetch_openml  # Загрузка наборов данных из OpenML
from sklearn.manifold import TSNE  # Уменьшение размерности (визуализация)
from sklearn.decomposition import PCA  # Уменьшение размерности (анализ)
from sklearn.mixture import GaussianMixture  # Гауссовы смеси (кластеризация)
from mpl_toolkits.mplot3d import Axes3D  # 3D графики matplotlib
from clustergram import Clustergram  # Визуализация результатов кластеризации
from sklearn import datasets  # Основные наборы данных sklearn
from sklearn.datasets import make_classification, make_moons  # Генерация синтетических данных
from sklearn.preprocessing import PolynomialFeatures  # Создание полиномиальных признаков
from sklearn.manifold import TSNE  # Дублирующийся импорт (можно удалить)
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, PowerTransformer, QuantileTransformer  # Методы масштабирования признаков
from sklearn.feature_extraction.text import TfidfVectorizer  # Преобразование текста в TF-IDF признаки
from sklearn.feature_selection import SelectKBest, VarianceThreshold  # Методы отбора признаков
from joblib import parallel_backend  # Параллельные вычисления
from sklearn.svm import SVC  # Метод опорных векторов (классификация)
from sklearn.tree import DecisionTreeClassifier, plot_tree  # Дерево решений и его визуализация
from sklearn.naive_bayes import MultinomialNB  # Наивный Байес для текста
from sklearn.feature_extraction.text import CountVectorizer  # Преобразование текста в матрицу частот
from sklearn.neighbors import KNeighborsClassifier  # Метод k-ближайших соседей
from sklearn.datasets import make_classification, make_moons  # Дублирующийся импорт (можно удалить)
from sklearn.pipeline import make_pipeline  # Создание конвейеров обработки
from sklearn.metrics import accuracy_score, classification_report  # Метрики классификации (точность, отчёт)

# %% [markdown]
# ## Convex hull - Выпуклая оболочка

# %%
from scipy.spatial import ConvexHull  # Вычисление выпуклой оболочки для набора точек

# %% [markdown]
# ## Clustering / modeling - Кластеризация/моделирование

# %%
from scipy.cluster.hierarchy import dendrogram, linkage  # Иерархическая кластеризация и визуализация дендрограмм
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, SpectralClustering  # Алгоритмы кластеризации

# %% [markdown]
# ## Comet ML - Comet ML платформа экспериментов

# %%
from comet_ml import Experiment  # Основной класс для трекинга экспериментов ML
from comet_ml import start  # Функция для запуска сессии трекинга
from comet_ml.integration.pytorch import log_model  # Логирование моделей PyTorch в Comet.ml

# %% [markdown]
# ## ML Metrics - Метрики ML

# %%
from sklearn.metrics import (  # Импорт всех метрик одним блоком
  accuracy_score, precision_score, recall_score, f1_score,  # Основные метрики классификации
  roc_auc_score, confusion_matrix, classification_report, log_loss,  # ROC-анализ, матрица ошибок, логлосс
  average_precision_score, brier_score_loss, matthews_corrcoef,  # Доп.метрики классификации
  cohen_kappa_score, hamming_loss, jaccard_score, zero_one_loss,  # Метрики для многоклассовой классификации
  mean_absolute_error, mean_squared_error, mean_squared_log_error,  # Метрики регрессии
  median_absolute_error, r2_score, explained_variance_score,  # Метрики регрессии
  max_error, mean_poisson_deviance  # Дополнительные метрики регрессии
)
from sklearn.metrics import silhouette_score  # Метрика качества кластеризации
from sklearn.metrics.cluster import completeness_score, homogeneity_score, v_measure_score, rand_score  # Метрики оценки кластеризации

# %% [markdown]
# ## Linear models / Regression - Линейные модели / Регрессия

# %%
from sklearn.linear_model import (  # Линейные модели машинного обучения
    LinearRegression,  # Простая линейная регрессия
    Ridge,  # Гребневая регрессия (L2-регуляризация)
    Lasso,  # Лассо-регрессия (L1-регуляризация)
    ElasticNet,  # Эластичная сеть (комбинация L1 и L2)
    LogisticRegression,  # Логистическая регрессия для классификации
    SGDRegressor,  # Регрессия со стохастическим градиентным спуском
    SGDClassifier,  # Классификация со стохастическим градиентным спуском
    Perceptron,  # Простейшая нейронная модель (персептрон)
    PassiveAggressiveClassifier,  # Пассивно-агрессивный классификатор
    RANSACRegressor,  # Регрессия с методом RANSAC (устойчивая к выбросам)
    HuberRegressor,  # Регрессия Хубера (устойчивая к выбросам)
    QuantileRegressor  # Квантильная регрессия
)

# %% [markdown]
# ## Ensemble methods - Ансамблевые методы

# %%
from sklearn.ensemble import (  # Ансамблевые методы машинного обучения
    RandomForestRegressor,  # Случайный лес для регрессии
    RandomForestClassifier,  # Случайный лес для классификации
    GradientBoostingRegressor,  # Градиентный бустинг для регрессии
    GradientBoostingClassifier,  # Градиентный бустинг для классификации
    AdaBoostClassifier,  # Адаптивный бустинг для классификации
    AdaBoostRegressor,  # Адаптивный бустинг для регрессии
    ExtraTreesClassifier,  # Крайне случайные деревья для классификации
    ExtraTreesRegressor,  # Крайне случайные деревья для регрессии
    HistGradientBoostingClassifier,  # Быстрый градиентный бустинг на гистограммах (классификация)
    HistGradientBoostingRegressor,  # Быстрый градиентный бустинг на гистограммах (регрессия)
    BaggingClassifier,  # Бэггинг для классификации
    BaggingRegressor,  # Бэггинг для регрессии
    VotingClassifier,  # Голосующий ансамбль для классификации
    VotingRegressor  # Голосующий ансамбль для регрессии
)

# %% [markdown]
# ## Model selection / data splitting - Выбор модели / разбиение данных

# %%
from sklearn.model_selection import (  # Методы разделения данных и валидации моделей
    train_test_split,  # Разделение на обучающую и тестовую выборки
    KFold,  # K-кратная кросс-валидация
    LeaveOneOut,  # Кросс-валидация по принципу "один остаётся"
    cross_validate  # Функция для проведения кросс-валидации с оценкой нескольких метрик
)

# %% [markdown]
# # Общее

# %%
# 1. БАЗОВЫЕ БИБЛИОТЕКИ PYTHON
import warnings, os, time, sys, json, math, random # Обработка предупреждений, работа с ОС, время, системные параметры, JSON, математика, случайные числа
from io import StringIO # Работа со строкой как с файловым объектом
from itertools import chain, tee # Эффективная работа с итераторами
from contextlib import contextmanager # Создание контекстных менеджеров (для with-блоков)

# 2. НАУЧНЫЕ ВЫЧИСЛЕНИЯ И ДАННЫЕ
import numpy as np # Массивы и математические операции
import pandas as pd # Табличные данные и анализ
import scipy as sp # Научные вычисления и статистика
import statsmodels.api as sm # Статистические модели и тесты
import torch # Глубокое обучение и нейронные сети

# 3. МАШИННОЕ ОБУЧЕНИЕ (SCIKIT-LEARN)
import sklearn as sk # Основная библиотека ML
from sklearn import datasets, model_selection, preprocessing, decomposition, manifold, feature_selection, metrics # Основные модули scikit-learn
from sklearn.datasets import fetch_openml, make_classification, make_moons # Загрузка и генерация данных
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, PowerTransformer, QuantileTransformer, PolynomialFeatures # Масштабирование и преобразование признаков
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer # Преобразование текста в числовые признаки
from sklearn.feature_selection import SelectKBest, VarianceThreshold # Отбор наиболее важных признаков
from sklearn.model_selection import train_test_split, KFold, LeaveOneOut, cross_validate # Разделение данных и валидация моделей
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, LogisticRegression # Линейные модели для регрессии и классификации
from sklearn.svm import SVC # Метод опорных векторов для классификации
from sklearn.tree import DecisionTreeClassifier, plot_tree # Деревья решений и их визуализация
from sklearn.naive_bayes import MultinomialNB # Наивный Байес для текстовой классификации
from sklearn.neighbors import KNeighborsClassifier # К-ближайших соседей для классификации
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, SpectralClustering # Алгоритмы кластеризации
from sklearn.mixture import GaussianMixture # Гауссовы смеси для кластеризации
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor # Ансамблевые методы (случайные леса, градиентный бустинг)
from sklearn.pipeline import make_pipeline # Конвейеры для объединения этапов обработки
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, silhouette_score # Метрики оценки моделей
from joblib import parallel_backend # Параллельные вычисления

# 4. ВИЗУАЛИЗАЦИЯ
import matplotlib.pyplot as plt # Основная библиотека для графиков
import seaborn as sns # Статистическая визуализация на основе matplotlib
import plotly.express as px # Интерактивная визуализация для веб-браузеров

# 5. СПЕЦИАЛИЗИРОВАННЫЕ БИБЛИОТЕКИ
import geopandas as gpd # Геопространственные данные и карты
from scipy import stats, spatial, cluster # Статистика, пространственные алгоритмы, кластеризация из SciPy
from shapely.geometry import Point, Polygon # Геометрические объекты (точки, полигоны)
from geopy.geocoders import Nominatim # Преобразование адресов в координаты
from statsmodels.tsa.arima.model import ARIMA # ARIMA-модели для временных рядов
from statsmodels.tsa.statespace.sarimax import SARIMAX # Сезонные ARIMA-модели
from arch import arch_model # Модели волатильности финансовых временных рядов
from clustergram import Clustergram # Визуализация результатов кластеризации
from comet_ml import Experiment, start # Трекинг экспериментов машинного обучения
from comet_ml.integration.pytorch import log_model # Интеграция моделей PyTorch с Comet.ml
from lightautoml.automl.presets.tabular_presets import TabularAutoML # Автоматическое ML для табличных данных
from lightautoml.tasks import Task # Определение типа задачи ML (классификация, регрессия)

# %% [markdown]
# ## Обработка выбросов - ML

# %%
from  sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# %% [markdown]
# ## Трансформация распределения

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %% [markdown]
# ## Дата и расстояние

# %%
from geopy.geocoders import Nominatim
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

# %%
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import roc_curve

# %%
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## Базовая оптимизация

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import optuna
import hyperopt
from hyperopt import hp, fmin, tpe, Trials
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
# ----> 2 import optuna
#       3 import hyperopt
#       4 from hyperopt import hp, fmin, tpe, Trials
#
# ModuleNotFoundError: No module named 'optuna'

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import RidgeCV

# %% [markdown]
# ## Бегинг, Стекинг Бустинг

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.pipeline import make_pipeline

# %% [markdown]
# Pipeline

# %%
#загрузим основные библиотеки

from sklearn.pipeline import Pipeline
 
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
